# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cd /content/drive/MyDrive/pai2 && . colab.sh
# !cd /content/code && . .venv/bin/activate && pip install ipykernel

# %%
# !cd /content/code && . .venv/bin/activate && python -u solution.py

# %%
# !cd /content/code && . .venv/bin/activate && CALIBRATION_THRESHOLD='0.73' python -u checker_client.py
